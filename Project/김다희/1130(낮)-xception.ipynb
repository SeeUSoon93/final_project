# %%
import os
import tempfile
import numpy as np
import pandas as pd
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import regularizers, layers, models, regularizers
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import (
    GlobalAveragePooling1D,
    LSTM, 
    Dense, 
    Input, 
    concatenate,
    TimeDistributed,
    Flatten
)
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications.xception import preprocess_input

# %%
train_dir = 'data/train'
test_dir = 'data/test'
# 비디오 파일 목록과 태그를 포함하는 리스트를 만드는 함수
def create_data_list(data_dir):
    data_list = []
    # data_dir 안의 각 디렉토리에 대해 반복
    for item in os.listdir(data_dir):
        item_path = os.path.join(data_dir, item)  # 아이템의 전체 경로
        # 해당 경로가 디렉토리인지 확인
        if os.path.isdir(item_path):
            # 디렉토리 내의 모든 파일을 나열
            for file_name in os.listdir(item_path):
                # 파일이 .mp4 파일인지 확인
                if file_name.endswith('.mp4'):
                    # 리스트에 태그와 파일 경로를 추가
                    data_list.append((item, str(data_dir+'/'+item)+'/'+file_name))
    return data_list

# 함수를 사용해서 리스트를 생성
train_list = create_data_list(train_dir)
test_list = create_data_list(test_dir)
# 리스트에서 데이터프레임을 생성
train_df = pd.DataFrame(data=train_list, columns=['tag', 'video_name'])
test_df = pd.DataFrame(data=test_list, columns=['tag', 'video_name'])
# 필요한 경우 열 순서를 수정
train_df = train_df.loc[:, ['tag', 'video_name']]
test_df = test_df.loc[:, ['tag', 'video_name']]
# 데이터프레임을 CSV 파일로 저장
train_file_path = 'train.csv'
test_file_path = 'test.csv'
train_df.to_csv(train_file_path, encoding='utf-8-sig', index=False)
test_df.to_csv(test_file_path, encoding='utf-8-sig', index=False)

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")
print(f"Total video for training: {len(train_df)}")
print(f"Total video for testing: {len(test_df)}")
# Out:
# Total video for training: 50
# Total video for testing: 15

# %%
# GPU 장치 목록 가져오기
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    # GPU의 가상 메모리 제한을 6GB로 설정
    tf.config.experimental.set_virtual_device_configuration(
        gpu_devices[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024 * 6)]
    )
    # set_memory_growth는 set_virtual_device_configuration과 함께 사용할 수 없습니다
else:
    print('Using CPU')
# Out:
# Using CPU

# %%
IMG_SIZE = 299
BATCH_SIZE = 64
EPOCHS = 70

MAX_SEQ_LENGTH = 5
NUM_FEATURES = 512
SKELETON_FEATURES = 33*4
HAND_FEATURES = 21*3*2
ARM_ANGLE_FEATURES = 2
N_CLASSES = len(np.unique(train_df["tag"]))

# %%
# 주어진 이미지에서 중앙에 맞춰 정사각형으로 잘나내는 함수
def crop_center_square(frame):
    # 이미지의 높이(y)와 너비(x)를 가져옴
    y, x = frame.shape[0:2]
    # 이미지의 높이와 너비 중 더 작은 값을 선택하여 정사각형의 크기를 결정
    min_dim = min(y, x)
    # 정사각형을 이미지 중앙에 위치시키기 위해 시작점의 x좌표와 y좌표를 계산
    start_x = (x // 2) - (min_dim // 2)
    start_y = (y // 2) - (min_dim // 2)
    # 계산된 시작점과 정사각형의 크기를 이용하여 이미지의 중앙 부분을 잘라냅니다.
    return frame[start_y : start_y + min_dim, start_x : start_x + min_dim]

# %%
def calculate_angle(a, b, c):
    a = np.array([a.x, a.y])  # 첫 번째 점
    b = np.array([b.x, b.y])  # 중간 점 (팔꿈치)
    c = np.array([c.x, c.y])  # 세 번째 점 (손목)

    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)

    if angle > 180.0:
        angle = 360 - angle

    return angle

# %%
# 비디오 파일을 로드하고, 각 프레임을 처리하여 배열로 반환하는 함수
def load_video(path, max_frames=0, resize=(IMG_SIZE, IMG_SIZE)):
    mp_hands = mp.solutions.hands
    mp_pose = mp.solutions.pose

    pose = mp_pose.Pose(static_image_mode=False, model_complexity=1, smooth_landmarks=True)
    hands = mp_hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5)
    # OpenCV를 사용하여 비디오 파일 열기
    cap = cv2.VideoCapture(path)
    frames = []
    skeletons = []  # 스켈레톤 데이터
    hand_landmarks = []  # 손 데이터
    arm_angles = []  # 팔 각도 데이터

    try:
        while True:
            # 비디오에서 프레임을 하나씩 읽기
            ret, frame = cap.read()
            # 읽을 프레임이 없으면 반복문을 종료
            if not ret:
                break
            # 읽은 프레임에서 중앙의 정사각형 부분을 잘라냄
            frame = crop_center_square(frame)
            # 프레임의 크기를 지정된 크기로 조절
            frame = cv2.resize(frame, resize)            
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            
            # Mediapipe를 사용하여 스켈레톤 추출
            hands_results = hands.process(frame_rgb)
            pose_results = pose.process(frame_rgb)
           
            if pose_results.pose_landmarks:
                right_shoulder = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER]
                right_elbow = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW]
                right_wrist = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_WRIST]

                left_shoulder = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_SHOULDER]
                left_elbow = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW]
                left_wrist = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_WRIST]

                right_arm_angle = calculate_angle(right_shoulder, right_elbow, right_wrist)
                left_arm_angle = calculate_angle(left_shoulder, left_elbow, left_wrist)

                arm_angles.append((right_arm_angle, left_arm_angle))
                skeletons.append(pose_results.pose_landmarks.landmark)
                mp.solutions.drawing_utils.draw_landmarks(
                    frame, pose_results.pose_landmarks, mp_pose.POSE_CONNECTIONS)            
                
            if hands_results.multi_hand_landmarks:
                hand_landmarks_data = hands_results.multi_hand_landmarks
                hand_landmarks.append(hand_landmarks_data)
                for hand_lm in hand_landmarks_data:
                    mp.solutions.drawing_utils.draw_landmarks(
                        frame, hand_lm, mp_hands.HAND_CONNECTIONS)
            
            cv2.imshow('Video Frame', frame)
            cv2.waitKey(30)
            # OpenCV는 BGR 색상 순서를 사용하므로, 이를 RGB 순서로 변경
            frame = frame[:, :, [2, 1, 0]]
            # 처리된 프레임을 프레임 리스트에 추가
            frames.append(frame)
            # max_frames가 지정된 경우, 지정된 수의 프레임만큼만 처리
            if len(frames) == max_frames:
                break
    finally:
        # 비디오 파일을 닫기
        cv2.destroyAllWindows()
        cap.release()
        pose.close
        hands.close
    return np.array(frames), skeletons, hand_landmarks, np.array(arm_angles)

# %%
# 증강을 위한 함수 정의
def rotated_frame(frame, angle_range=10):
    # 랜덤 회전을 위한 각도 설정
    angle = random.uniform(-angle_range, angle_range)
    # 회전 변환 행렬 계산
    rotation_matrix = cv2.getRotationMatrix2D((frame.shape[1] / 2, frame.shape[0] / 2), angle, 1)
    # 프레임 회전
    rotated_frame = cv2.warpAffine(frame, rotation_matrix, (frame.shape[1], frame.shape[0]))  
    
    return rotated_frame

# %%
# 증강을 위한 함수 정의
def adjusted_frame(frame):
    adjusted_frame = cv2.convertScaleAbs(frame, alpha=1, beta=random.uniform(-30, 30))    
    return adjusted_frame

# %%
# 증강용
def load_roatated_video(path, max_frames=0, resize=(IMG_SIZE, IMG_SIZE)):
    mp_hands = mp.solutions.hands
    mp_pose = mp.solutions.pose

    pose = mp_pose.Pose(static_image_mode=False, model_complexity=1, smooth_landmarks=True)
    hands = mp_hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5)
    # OpenCV를 사용하여 비디오 파일 열기
    cap = cv2.VideoCapture(path)
    frames = []
    skeletons = []  # 스켈레톤 데이터
    hand_landmarks = []  # 손 데이터
    arm_angles = []  # 팔 각도 데이터

    try:
        while True:
            # 비디오에서 프레임을 하나씩 읽기
            ret, frame = cap.read()
            # 읽을 프레임이 없으면 반복문을 종료
            if not ret:
                break
            # 읽은 프레임에서 중앙의 정사각형 부분을 잘라냄
            frame = crop_center_square(frame)
            # 프레임의 크기를 지정된 크기로 조절
            frame = cv2.resize(frame, resize)
            frame = rotated_frame(frame)
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            
            # Mediapipe를 사용하여 스켈레톤 추출
            hands_results = hands.process(frame_rgb)
            pose_results = pose.process(frame_rgb)
           
            if pose_results.pose_landmarks:
                right_shoulder = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER]
                right_elbow = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW]
                right_wrist = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_WRIST]

                left_shoulder = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_SHOULDER]
                left_elbow = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW]
                left_wrist = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_WRIST]

                right_arm_angle = calculate_angle(right_shoulder, right_elbow, right_wrist)
                left_arm_angle = calculate_angle(left_shoulder, left_elbow, left_wrist)

                arm_angles.append((right_arm_angle, left_arm_angle))
                skeletons.append(pose_results.pose_landmarks.landmark)
                mp.solutions.drawing_utils.draw_landmarks(
                    frame, pose_results.pose_landmarks, mp_pose.POSE_CONNECTIONS)            
                
            if hands_results.multi_hand_landmarks:
                hand_landmarks_data = hands_results.multi_hand_landmarks
                hand_landmarks.append(hand_landmarks_data)
                for hand_lm in hand_landmarks_data:
                    mp.solutions.drawing_utils.draw_landmarks(
                        frame, hand_lm, mp_hands.HAND_CONNECTIONS)
            
            cv2.imshow('Video Frame', frame)
            cv2.waitKey(30)
            # OpenCV는 BGR 색상 순서를 사용하므로, 이를 RGB 순서로 변경
            frame = frame[:, :, [2, 1, 0]]
            # 처리된 프레임을 프레임 리스트에 추가
            frames.append(frame)
            # max_frames가 지정된 경우, 지정된 수의 프레임만큼만 처리
            if len(frames) == max_frames:
                break
    finally:
        # 비디오 파일을 닫기
        cv2.destroyAllWindows()
        cap.release()
        pose.close
        hands.close
    return np.array(frames), skeletons, hand_landmarks, np.array(arm_angles)

# %%
# 증강용
def load_adjusted_video(path, max_frames=0, resize=(IMG_SIZE, IMG_SIZE)):
    mp_hands = mp.solutions.hands
    mp_pose = mp.solutions.pose

    pose = mp_pose.Pose(static_image_mode=False, model_complexity=1, smooth_landmarks=True)
    hands = mp_hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5)
    # OpenCV를 사용하여 비디오 파일 열기
    cap = cv2.VideoCapture(path)
    frames = []
    skeletons = []  # 스켈레톤 데이터
    hand_landmarks = []  # 손 데이터
    arm_angles = []  # 팔 각도 데이터

    try:
        while True:
            # 비디오에서 프레임을 하나씩 읽기
            ret, frame = cap.read()
            # 읽을 프레임이 없으면 반복문을 종료
            if not ret:
                break
            # 읽은 프레임에서 중앙의 정사각형 부분을 잘라냄
            frame = crop_center_square(frame)
            # 프레임의 크기를 지정된 크기로 조절
            frame = cv2.resize(frame, resize)
            frame = rotated_frame(frame)
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            
            # Mediapipe를 사용하여 스켈레톤 추출
            hands_results = hands.process(frame_rgb)
            pose_results = pose.process(frame_rgb)
           
            if pose_results.pose_landmarks:
                right_shoulder = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER]
                right_elbow = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW]
                right_wrist = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_WRIST]

                left_shoulder = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_SHOULDER]
                left_elbow = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ELBOW]
                left_wrist = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_WRIST]

                right_arm_angle = calculate_angle(right_shoulder, right_elbow, right_wrist)
                left_arm_angle = calculate_angle(left_shoulder, left_elbow, left_wrist)

                arm_angles.append((right_arm_angle, left_arm_angle))
                skeletons.append(pose_results.pose_landmarks.landmark)
                mp.solutions.drawing_utils.draw_landmarks(
                    frame, pose_results.pose_landmarks, mp_pose.POSE_CONNECTIONS)            
                
            if hands_results.multi_hand_landmarks:
                hand_landmarks_data = hands_results.multi_hand_landmarks
                hand_landmarks.append(hand_landmarks_data)
                for hand_lm in hand_landmarks_data:
                    mp.solutions.drawing_utils.draw_landmarks(
                        frame, hand_lm, mp_hands.HAND_CONNECTIONS)
            
            cv2.imshow('Video Frame', frame)
            cv2.waitKey(30)
            # OpenCV는 BGR 색상 순서를 사용하므로, 이를 RGB 순서로 변경
            frame = frame[:, :, [2, 1, 0]]
            # 처리된 프레임을 프레임 리스트에 추가
            frames.append(frame)
            # max_frames가 지정된 경우, 지정된 수의 프레임만큼만 처리
            if len(frames) == max_frames:
                break
    finally:
        # 비디오 파일을 닫기
        cv2.destroyAllWindows()
        cap.release()
        pose.close
        hands.close
    return np.array(frames), skeletons, hand_landmarks, np.array(arm_angles)

# %%
# 특징추출
def build_feature_extractor():
    base_model = Xception(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(299, 299, 3),  # Xception의 기본 입력 크기
    )
    image_input = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    preprocessed_image = preprocess_input(image_input)
    image_features = base_model(preprocessed_image)

    # Mediapipe 데이터 처리
    mediapipe_input = keras.Input((258,))
    mediapipe_features = keras.layers.Dense(258, activation="relu")(mediapipe_input)
    mediapipe_features = keras.layers.Dropout(0.3)(mediapipe_features)  # Dropout 추가

    # 팔 각도 데이터 처리
    arm_angle_input = keras.Input((2,))
    arm_angle_features = keras.layers.Dense(16, activation="relu")(arm_angle_input)
    arm_angle_features = keras.layers.Dropout(0.3)(arm_angle_features)  # Dropout 추가

    # 데이터 결합 및 추가 처리
    combined_features = keras.layers.concatenate(
        [image_features, mediapipe_features, arm_angle_features])
    combined_features = keras.layers.BatchNormalization()(combined_features)
    combined_features = keras.layers.Dense(
        512, activation="relu", kernel_regularizer=regularizers.l2(0.01))(combined_features)

    return keras.Model(inputs=[image_input, mediapipe_input, arm_angle_input], outputs=combined_features, name="feature_extractor")

# %%
# 손 랜드마크를 2개로 제한한 코드
def preprocess_skeleton_data(skeleton):
    # 스켈레톤 데이터가 없는 경우 빈 벡터 반환
    if not skeleton:
        return np.zeros(SKELETON_FEATURES)
    # 스켈레톤 데이터를 1차원 배열로 변환
    skeleton_array = np.array([[lm.x, lm.y, lm.z] for lm in skeleton]).flatten()    
    # 부족한 부분을 0으로 채우기
    skeleton_array = np.pad(skeleton_array, ((0, max(0, SKELETON_FEATURES - len(skeleton_array)))))    
    return skeleton_array

def preprocess_hand_data(hand_landmarks):
    # 손 랜드마크 데이터가 없는 경우 빈 벡터 반환
    if not hand_landmarks or len(hand_landmarks) < 2:
        return np.zeros(HAND_FEATURES)
    
    # 첫 번째와 두 번째 손에 대한 랜드마크만 처리
    hand_data = []
    for hand_lm in hand_landmarks[:2]:  # 첫 번째와 두 번째 손만 처리
        lm_array = np.array([[lm.x, lm.y, lm.z] for lm in hand_lm.landmark]).flatten()
        hand_data.extend(lm_array)

    # 부족한 부분을 0으로 채우기
    hand_data = np.pad(hand_data, ((0, max(0, HAND_FEATURES - len(hand_data)))))

    return np.array(hand_data)

def preprocess_arm_angle_data(arm_angles):
    # 팔 각도 데이터가 없는 경우 빈 벡터 반환
    if not arm_angles.size == 0:
        return np.zeros(2)  # 오른팔, 왼팔 각각의 각도
    return np.array(arm_angles)

def preprocess_image(frame):
    # frame을 이미지 배열로 변환
    frame = image.img_to_array(frame)
    # EfficientNetB0에 맞는 전처리 적용
    frame = preprocess_input(frame)
    return frame

# %%
def prepare_all_video(df):
    num_samples = len(df)
    video_paths = df["video_name"].values.tolist()

    # Mediapipe 데이터를 저장할 배열 초기화                          
    frame_skeletons = np.zeros(shape=(num_samples, MAX_SEQ_LENGTH, SKELETON_FEATURES), dtype="float32")
    frame_hands = np.zeros(shape=(num_samples, MAX_SEQ_LENGTH, HAND_FEATURES), dtype="float32")    
    frame_masks = np.zeros(shape=(num_samples, MAX_SEQ_LENGTH), dtype="bool")
    frame_features = np.zeros(shape=(num_samples, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32")
    frame_images = np.zeros(shape=(num_samples, MAX_SEQ_LENGTH, IMG_SIZE, IMG_SIZE, 3), dtype="float32")
    frame_arm_angles = np.zeros(shape=(num_samples, MAX_SEQ_LENGTH, ARM_ANGLE_FEATURES), dtype="float32")  # 2는 팔 각도 데이터 차원
    
    # 특징 추출기 모델 초기화
    feature_extractor = build_feature_extractor()
    
    load_list = ["load_video","load_roatated_video","load_adjusted_video"]
    for load_func_name in load_list:
        load_func = globals().get(load_func_name)
        for idx, path in enumerate(video_paths):
            frames, skeletons, hands, arm_angles = load_video(path)
            video_length = min(MAX_SEQ_LENGTH, len(frames))

            for i in range(video_length):
                # 이미지 데이터 전처리 및 특징 추출
                image_feature = preprocess_image(frames[i])
                image_feature = np.expand_dims(image_feature, axis=0)

                # Mediapipe 데이터 전처리
                skeleton_feature = preprocess_skeleton_data(skeletons[i])
                hand_feature = preprocess_hand_data(hands[i])
                combined_mediapipe_data = np.concatenate([skeleton_feature, hand_feature])
                combined_mediapipe_data = np.expand_dims(combined_mediapipe_data, axis=0)

                # 팔 각도 데이터 전처리
                arm_angle_feature = preprocess_arm_angle_data(arm_angles[i])
                arm_angle_feature = np.expand_dims(arm_angle_feature, axis=0)

                # 모델 예측
                try:
                    # 특징 추출기 모델에 이미지, Mediapipe 데이터, 팔 각도 데이터 전달
                    frame_feature = feature_extractor.predict([image_feature, combined_mediapipe_data, arm_angle_feature], verbose=0)
                    frame_features[idx, i, :] = frame_feature.squeeze()  # 예측 결과 저장, .squeeze()로 불필요한 차원 제거
                except Exception as e:
                    print(f"Error during prediction at index {idx}, frame {i}: {e}")
                    # 오류 발생시 해당 프레임을 0으로 설정하거나 다른 처리를 수행
                    frame_features[idx, i, :] = np.zeros(NUM_FEATURES)
                    frame_masks[idx, i] = 0  # 오류가 발생한 프레임은 마스크에서 제외

                # 데이터 저장
                frame_images[idx, i, :] = frames[i]  # 원본 이미지 데이터 저장
                frame_skeletons[idx, i, :] = skeleton_feature
                frame_hands[idx, i, :] = hand_feature
                frame_arm_angles[idx, i, :] = arm_angle_feature
                frame_masks[idx, i] = 1
            
    # 반환 값에 Mediapipe 데이터 포함
    return (frame_features, frame_skeletons, frame_hands, frame_arm_angles, frame_masks)

# %%
train_data = prepare_all_video(train_df)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 3s 0us/step

# %%
train_label_processor = keras.layers.StringLookup(num_oov_indices=0, vocabulary=np.unique(train_df["tag"]))
train_labels = train_df["tag"].values
train_labels = train_label_processor(train_labels[..., None]).numpy()
train_labels = np.squeeze(train_labels)

# %%
test_data = prepare_all_video(test_df)

# %%
test_label_processor = keras.layers.StringLookup(num_oov_indices=0, vocabulary=np.unique(test_df["tag"]))
test_labels = test_df["tag"].values
test_labels = test_label_processor(test_labels[..., None]).numpy()
test_labels = np.squeeze(test_labels)

# %%
# 데이터를 파일에 저장
with open('train_data.pkl', 'wb') as file:
    pickle.dump(train_data, file)
with open('test_data.pkl', 'wb') as file:
    pickle.dump(test_data, file)

# %%
with open('train_data.pkl', 'rb') as file:
    train_data = pickle.load(file)
with open('test_data.pkl', 'rb') as file:
    test_data = pickle.load(file)

# %%
def get_sequence_model():
    class_vocab = train_label_processor.get_vocabulary()
    
    # 입력 레이어
    frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))
    skeleton_input = keras.Input((MAX_SEQ_LENGTH, SKELETON_FEATURES))
    hand_input = keras.Input((MAX_SEQ_LENGTH, HAND_FEATURES))
    arm_angle_input = keras.Input((MAX_SEQ_LENGTH, ARM_ANGLE_FEATURES))  # 팔 각도 데이터 입력 레이어
    mask_input = keras.Input((MAX_SEQ_LENGTH,), dtype="bool")
    
    # LSTM 레이어
    x = LSTM(64, return_sequences=True)(frame_features_input, mask=mask_input)
    x = LSTM(32, return_sequences=False)(x)  # 시퀀스의 마지막 출력만 사용    

    y_skeleton = GlobalAveragePooling1D()(skeleton_input)
    y_hand = GlobalAveragePooling1D()(hand_input)
    y_arm_angle = GlobalAveragePooling1D()(arm_angle_input)
    
    combined = concatenate([x, y_skeleton, y_hand, y_arm_angle])

    # 추가 처리 및 출력 레이어
    z = Dense(16, activation="relu", kernel_regularizer=regularizers.l2(0.01))(combined)
    output = Dense(len(class_vocab), activation="softmax", kernel_regularizer=regularizers.l2(0.01))(z)
    
    # 모델 생성 및 컴파일
    lstm_model = keras.Model([frame_features_input, skeleton_input, hand_input, arm_angle_input, mask_input], output)
    lstm_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
    
    return lstm_model

# %%
EPOCHS = 200
BATCH_SIZE= 64
def run_experiment():
    filepath = "tmp/video_classifier_lstm.h5"
    checkpoint = keras.callbacks.ModelCheckpoint(
        filepath, save_weights_only=True, save_best_only=True, verbose=1)

    seq_model = get_sequence_model()
    # 모델 학습
    history = seq_model.fit(
        [train_data[0], train_data[1], train_data[2], train_data[3], train_data[4]],
        train_labels,
        batch_size=BATCH_SIZE,
        validation_split=0.1,
        epochs=EPOCHS,
        callbacks=[checkpoint],
    )

    seq_model.load_weights(filepath)
    
    # 테스트 데이터에 대한 평가
    _, accuracy = seq_model.evaluate(
        [test_data[0], test_data[1], test_data[2], test_data[3], test_data[4]],
        test_labels
    )
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    
    # 손실 및 정확도 그래프 출력
    plt.figure(figsize=(10, 4))
    # 손실 그래프
    ax1 = plt.subplot(1, 1, 1)
    ax1.plot(history.history['loss'], label='Train Loss', color='blue')
    ax1.plot(history.history['val_loss'], label='Validation Loss', color='blue', linestyle='dashed')
    ax1.set_title('Training and Validation Loss and Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss', color='blue')
    ax1.tick_params(axis='y', labelcolor='blue')
    ax1.legend(loc='upper left')
    # 정확도 그래프를 같은 그래프에 추가
    ax2 = ax1.twinx()
    ax2.plot(history.history['accuracy'], label='Train Accuracy', color='green')
    ax2.plot(history.history['val_accuracy'], label='Validation Accuracy', color='green', linestyle='dashed')
    ax2.set_ylabel('Accuracy', color='green')
    ax2.tick_params(axis='y', labelcolor='green')
    ax2.legend(loc='upper right')
    plt.show()
    
    seq_model.save('Xcepotion_model.h5')
    
    return history, seq_model

_, sequence_model = run_experiment()
# Out:
# Epoch 1/200
# 1/1 [==============================] - ETA: 0s - loss: 2.1862 - accuracy: 0.1111
# Epoch 1: val_loss improved from inf to 1.71409, saving model to tmp\video_classifier_lstm.h5
# 1/1 [==============================] - 10s 10s/step - loss: 2.1862 - accuracy: 0.1111 - val_loss: 1.7141 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 1/1 [==============================] - ETA: 0s - loss: 2.0856 - accuracy: 0.2222
# Epoch 2: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 2.0856 - accuracy: 0.2222 - val_loss: 1.9780 - val_accuracy: 0.0000e+00
# Epoch 3/200
# 1/1 [==============================] - ETA: 0s - loss: 2.0303 - accuracy: 0.2222
# Epoch 3: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 2.0303 - accuracy: 0.2222 - val_loss: 2.1540 - val_accuracy: 0.0000e+00
# Epoch 4/200
# 1/1 [==============================] - ETA: 0s - loss: 2.0053 - accuracy: 0.2222
# Epoch 4: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 2.0053 - accuracy: 0.2222 - val_loss: 2.2529 - val_accuracy: 0.0000e+00
# Epoch 5/200
# 1/1 [==============================] - ETA: 0s - loss: 1.9871 - accuracy: 0.2222
# Epoch 5: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.9871 - accuracy: 0.2222 - val_loss: 2.3059 - val_accuracy: 0.0000e+00
# Epoch 6/200
# 1/1 [==============================] - ETA: 0s - loss: 1.9712 - accuracy: 0.2000
# Epoch 6: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.9712 - accuracy: 0.2000 - val_loss: 2.3579 - val_accuracy: 0.0000e+00
# Epoch 7/200
# 1/1 [==============================] - ETA: 0s - loss: 1.9596 - accuracy: 0.2444
# Epoch 7: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.9596 - accuracy: 0.2444 - val_loss: 2.4166 - val_accuracy: 0.0000e+00
# Epoch 8/200
# 1/1 [==============================] - ETA: 0s - loss: 1.9488 - accuracy: 0.2222
# Epoch 8: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.9488 - accuracy: 0.2222 - val_loss: 2.4690 - val_accuracy: 0.0000e+00
# Epoch 9/200
# 1/1 [==============================] - ETA: 0s - loss: 1.9397 - accuracy: 0.2222
# Epoch 9: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.9397 - accuracy: 0.2222 - val_loss: 2.5020 - val_accuracy: 0.0000e+00
# Epoch 10/200
# 1/1 [==============================] - ETA: 0s - loss: 1.9329 - accuracy: 0.2222
# Epoch 10: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.9329 - accuracy: 0.2222 - val_loss: 2.5190 - val_accuracy: 0.0000e+00
# Epoch 11/200
# 1/1 [==============================] - ETA: 0s - loss: 1.9275 - accuracy: 0.2889
# Epoch 11: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.9275 - accuracy: 0.2889 - val_loss: 2.5261 - val_accuracy: 0.0000e+00
# Epoch 12/200
# 1/1 [==============================] - ETA: 0s - loss: 1.9239 - accuracy: 0.2444
# Epoch 12: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.9239 - accuracy: 0.2444 - val_loss: 2.5256 - val_accuracy: 0.0000e+00
# Epoch 13/200
# 1/1 [==============================] - ETA: 0s - loss: 1.9197 - accuracy: 0.2444
# Epoch 13: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.9197 - accuracy: 0.2444 - val_loss: 2.5160 - val_accuracy: 0.0000e+00
# Epoch 14/200
# 1/1 [==============================] - ETA: 0s - loss: 1.9155 - accuracy: 0.2444
# Epoch 14: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.9155 - accuracy: 0.2444 - val_loss: 2.4940 - val_accuracy: 0.0000e+00
# Epoch 15/200
# 1/1 [==============================] - ETA: 0s - loss: 1.9113 - accuracy: 0.2444
# Epoch 15: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.9113 - accuracy: 0.2444 - val_loss: 2.4669 - val_accuracy: 0.0000e+00
# Epoch 16/200
# 1/1 [==============================] - ETA: 0s - loss: 1.9071 - accuracy: 0.2444
# Epoch 16: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.9071 - accuracy: 0.2444 - val_loss: 2.4374 - val_accuracy: 0.0000e+00
# Epoch 17/200
# 1/1 [==============================] - ETA: 0s - loss: 1.9032 - accuracy: 0.2444
# Epoch 17: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.9032 - accuracy: 0.2444 - val_loss: 2.4120 - val_accuracy: 0.0000e+00
# Epoch 18/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8993 - accuracy: 0.2444
# Epoch 18: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8993 - accuracy: 0.2444 - val_loss: 2.3925 - val_accuracy: 0.0000e+00
# Epoch 19/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8955 - accuracy: 0.2444
# Epoch 19: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8955 - accuracy: 0.2444 - val_loss: 2.3802 - val_accuracy: 0.0000e+00
# Epoch 20/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8918 - accuracy: 0.2444
# Epoch 20: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 42ms/step - loss: 1.8918 - accuracy: 0.2444 - val_loss: 2.3718 - val_accuracy: 0.0000e+00
# Epoch 21/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8881 - accuracy: 0.2444
# Epoch 21: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8881 - accuracy: 0.2444 - val_loss: 2.3671 - val_accuracy: 0.0000e+00
# Epoch 22/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8846 - accuracy: 0.2667
# Epoch 22: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 44ms/step - loss: 1.8846 - accuracy: 0.2667 - val_loss: 2.3636 - val_accuracy: 0.0000e+00
# Epoch 23/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8810 - accuracy: 0.2667
# Epoch 23: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8810 - accuracy: 0.2667 - val_loss: 2.3628 - val_accuracy: 0.0000e+00
# Epoch 24/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8775 - accuracy: 0.2444
# Epoch 24: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.8775 - accuracy: 0.2444 - val_loss: 2.3634 - val_accuracy: 0.0000e+00
# Epoch 25/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8739 - accuracy: 0.2444
# Epoch 25: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8739 - accuracy: 0.2444 - val_loss: 2.3635 - val_accuracy: 0.0000e+00
# Epoch 26/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8702 - accuracy: 0.2444
# Epoch 26: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.8702 - accuracy: 0.2444 - val_loss: 2.3653 - val_accuracy: 0.0000e+00
# Epoch 27/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8665 - accuracy: 0.2444
# Epoch 27: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.8665 - accuracy: 0.2444 - val_loss: 2.3691 - val_accuracy: 0.0000e+00
# Epoch 28/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8629 - accuracy: 0.2667
# Epoch 28: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.8629 - accuracy: 0.2667 - val_loss: 2.3747 - val_accuracy: 0.0000e+00
# Epoch 29/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8593 - accuracy: 0.2667
# Epoch 29: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.8593 - accuracy: 0.2667 - val_loss: 2.3816 - val_accuracy: 0.0000e+00
# Epoch 30/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8558 - accuracy: 0.2444
# Epoch 30: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8558 - accuracy: 0.2444 - val_loss: 2.3889 - val_accuracy: 0.0000e+00
# Epoch 31/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8523 - accuracy: 0.2444
# Epoch 31: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8523 - accuracy: 0.2444 - val_loss: 2.4001 - val_accuracy: 0.0000e+00
# Epoch 32/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8487 - accuracy: 0.2444
# Epoch 32: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.8487 - accuracy: 0.2444 - val_loss: 2.4100 - val_accuracy: 0.0000e+00
# Epoch 33/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8452 - accuracy: 0.2444
# Epoch 33: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8452 - accuracy: 0.2444 - val_loss: 2.4171 - val_accuracy: 0.0000e+00
# Epoch 34/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8416 - accuracy: 0.2444
# Epoch 34: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8416 - accuracy: 0.2444 - val_loss: 2.4185 - val_accuracy: 0.0000e+00
# Epoch 35/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8379 - accuracy: 0.2444
# Epoch 35: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.8379 - accuracy: 0.2444 - val_loss: 2.4138 - val_accuracy: 0.0000e+00
# Epoch 36/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8340 - accuracy: 0.2444
# Epoch 36: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.8340 - accuracy: 0.2444 - val_loss: 2.4042 - val_accuracy: 0.0000e+00
# Epoch 37/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8302 - accuracy: 0.2444
# Epoch 37: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8302 - accuracy: 0.2444 - val_loss: 2.3874 - val_accuracy: 0.0000e+00
# Epoch 38/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8261 - accuracy: 0.2667
# Epoch 38: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8261 - accuracy: 0.2667 - val_loss: 2.3672 - val_accuracy: 0.0000e+00
# Epoch 39/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8218 - accuracy: 0.2889
# Epoch 39: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8218 - accuracy: 0.2889 - val_loss: 2.3494 - val_accuracy: 0.0000e+00
# Epoch 40/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8171 - accuracy: 0.2667
# Epoch 40: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.8171 - accuracy: 0.2667 - val_loss: 2.3326 - val_accuracy: 0.0000e+00
# Epoch 41/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8123 - accuracy: 0.2667
# Epoch 41: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8123 - accuracy: 0.2667 - val_loss: 2.3289 - val_accuracy: 0.0000e+00
# Epoch 42/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8071 - accuracy: 0.2667
# Epoch 42: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.8071 - accuracy: 0.2667 - val_loss: 2.3298 - val_accuracy: 0.0000e+00
# Epoch 43/200
# 1/1 [==============================] - ETA: 0s - loss: 1.8019 - accuracy: 0.2444
# Epoch 43: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.8019 - accuracy: 0.2444 - val_loss: 2.3493 - val_accuracy: 0.0000e+00
# Epoch 44/200
# 1/1 [==============================] - ETA: 0s - loss: 1.7966 - accuracy: 0.2444
# Epoch 44: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.7966 - accuracy: 0.2444 - val_loss: 2.3610 - val_accuracy: 0.0000e+00
# Epoch 45/200
# 1/1 [==============================] - ETA: 0s - loss: 1.7905 - accuracy: 0.2667
# Epoch 45: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.7905 - accuracy: 0.2667 - val_loss: 2.3534 - val_accuracy: 0.0000e+00
# Epoch 46/200
# 1/1 [==============================] - ETA: 0s - loss: 1.7845 - accuracy: 0.2667
# Epoch 46: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.7845 - accuracy: 0.2667 - val_loss: 2.3246 - val_accuracy: 0.0000e+00
# Epoch 47/200
# 1/1 [==============================] - ETA: 0s - loss: 1.7786 - accuracy: 0.2889
# Epoch 47: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.7786 - accuracy: 0.2889 - val_loss: 2.3225 - val_accuracy: 0.0000e+00
# Epoch 48/200
# 1/1 [==============================] - ETA: 0s - loss: 1.7717 - accuracy: 0.3556
# Epoch 48: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.7717 - accuracy: 0.3556 - val_loss: 2.3147 - val_accuracy: 0.0000e+00
# Epoch 49/200
# 1/1 [==============================] - ETA: 0s - loss: 1.7644 - accuracy: 0.3556
# Epoch 49: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.7644 - accuracy: 0.3556 - val_loss: 2.3021 - val_accuracy: 0.0000e+00
# Epoch 50/200
# 1/1 [==============================] - ETA: 0s - loss: 1.7569 - accuracy: 0.3333
# Epoch 50: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.7569 - accuracy: 0.3333 - val_loss: 2.3528 - val_accuracy: 0.0000e+00
# Epoch 51/200
# 1/1 [==============================] - ETA: 0s - loss: 1.7496 - accuracy: 0.3111
# Epoch 51: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.7496 - accuracy: 0.3111 - val_loss: 2.3853 - val_accuracy: 0.0000e+00
# Epoch 52/200
# 1/1 [==============================] - ETA: 0s - loss: 1.7416 - accuracy: 0.3556
# Epoch 52: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.7416 - accuracy: 0.3556 - val_loss: 2.3246 - val_accuracy: 0.0000e+00
# Epoch 53/200
# 1/1 [==============================] - ETA: 0s - loss: 1.7320 - accuracy: 0.3111
# Epoch 53: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.7320 - accuracy: 0.3111 - val_loss: 2.2928 - val_accuracy: 0.0000e+00
# Epoch 54/200
# 1/1 [==============================] - ETA: 0s - loss: 1.7232 - accuracy: 0.3333
# Epoch 54: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.7232 - accuracy: 0.3333 - val_loss: 2.3617 - val_accuracy: 0.0000e+00
# Epoch 55/200
# 1/1 [==============================] - ETA: 0s - loss: 1.7140 - accuracy: 0.3111
# Epoch 55: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.7140 - accuracy: 0.3111 - val_loss: 2.3010 - val_accuracy: 0.0000e+00
# Epoch 56/200
# 1/1 [==============================] - ETA: 0s - loss: 1.7059 - accuracy: 0.2889
# Epoch 56: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.7059 - accuracy: 0.2889 - val_loss: 2.3982 - val_accuracy: 0.0000e+00
# Epoch 57/200
# 1/1 [==============================] - ETA: 0s - loss: 1.6936 - accuracy: 0.3333
# Epoch 57: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.6936 - accuracy: 0.3333 - val_loss: 2.2846 - val_accuracy: 0.0000e+00
# Epoch 58/200
# 1/1 [==============================] - ETA: 0s - loss: 1.6847 - accuracy: 0.3333
# Epoch 58: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.6847 - accuracy: 0.3333 - val_loss: 2.3465 - val_accuracy: 0.0000e+00
# Epoch 59/200
# 1/1 [==============================] - ETA: 0s - loss: 1.6727 - accuracy: 0.3778
# Epoch 59: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.6727 - accuracy: 0.3778 - val_loss: 2.4341 - val_accuracy: 0.0000e+00
# Epoch 60/200
# 1/1 [==============================] - ETA: 0s - loss: 1.6616 - accuracy: 0.3778
# Epoch 60: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.6616 - accuracy: 0.3778 - val_loss: 2.2527 - val_accuracy: 0.0000e+00
# Epoch 61/200
# 1/1 [==============================] - ETA: 0s - loss: 1.6495 - accuracy: 0.4000
# Epoch 61: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.6495 - accuracy: 0.4000 - val_loss: 2.4094 - val_accuracy: 0.0000e+00
# Epoch 62/200
# 1/1 [==============================] - ETA: 0s - loss: 1.6358 - accuracy: 0.4222
# Epoch 62: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.6358 - accuracy: 0.4222 - val_loss: 2.3308 - val_accuracy: 0.0000e+00
# Epoch 63/200
# 1/1 [==============================] - ETA: 0s - loss: 1.6234 - accuracy: 0.4000
# Epoch 63: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.6234 - accuracy: 0.4000 - val_loss: 2.3834 - val_accuracy: 0.0000e+00
# Epoch 64/200
# 1/1 [==============================] - ETA: 0s - loss: 1.6135 - accuracy: 0.4667
# Epoch 64: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.6135 - accuracy: 0.4667 - val_loss: 2.5504 - val_accuracy: 0.0000e+00
# Epoch 65/200
# 1/1 [==============================] - ETA: 0s - loss: 1.5975 - accuracy: 0.4667
# Epoch 65: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.5975 - accuracy: 0.4667 - val_loss: 2.3080 - val_accuracy: 0.0000e+00
# Epoch 66/200
# 1/1 [==============================] - ETA: 0s - loss: 1.5818 - accuracy: 0.4222
# Epoch 66: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.5818 - accuracy: 0.4222 - val_loss: 2.5946 - val_accuracy: 0.0000e+00
# Epoch 67/200
# 1/1 [==============================] - ETA: 0s - loss: 1.5674 - accuracy: 0.5333
# Epoch 67: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.5674 - accuracy: 0.5333 - val_loss: 2.5452 - val_accuracy: 0.0000e+00
# Epoch 68/200
# 1/1 [==============================] - ETA: 0s - loss: 1.5519 - accuracy: 0.5111
# Epoch 68: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.5519 - accuracy: 0.5111 - val_loss: 2.5209 - val_accuracy: 0.0000e+00
# Epoch 69/200
# 1/1 [==============================] - ETA: 0s - loss: 1.5349 - accuracy: 0.4889
# Epoch 69: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.5349 - accuracy: 0.4889 - val_loss: 2.9202 - val_accuracy: 0.0000e+00
# Epoch 70/200
# 1/1 [==============================] - ETA: 0s - loss: 1.5307 - accuracy: 0.4889
# Epoch 70: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.5307 - accuracy: 0.4889 - val_loss: 2.3365 - val_accuracy: 0.2000
# Epoch 71/200
# 1/1 [==============================] - ETA: 0s - loss: 1.5258 - accuracy: 0.4444
# Epoch 71: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.5258 - accuracy: 0.4444 - val_loss: 2.7740 - val_accuracy: 0.0000e+00
# Epoch 72/200
# 1/1 [==============================] - ETA: 0s - loss: 1.4912 - accuracy: 0.5778
# Epoch 72: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.4912 - accuracy: 0.5778 - val_loss: 3.1771 - val_accuracy: 0.0000e+00
# Epoch 73/200
# 1/1 [==============================] - ETA: 0s - loss: 1.5061 - accuracy: 0.5333
# Epoch 73: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.5061 - accuracy: 0.5333 - val_loss: 2.7234 - val_accuracy: 0.0000e+00
# Epoch 74/200
# 1/1 [==============================] - ETA: 0s - loss: 1.4727 - accuracy: 0.4889
# Epoch 74: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.4727 - accuracy: 0.4889 - val_loss: 2.6459 - val_accuracy: 0.0000e+00
# Epoch 75/200
# 1/1 [==============================] - ETA: 0s - loss: 1.4916 - accuracy: 0.4222
# Epoch 75: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.4916 - accuracy: 0.4222 - val_loss: 2.9299 - val_accuracy: 0.0000e+00
# Epoch 76/200
# 1/1 [==============================] - ETA: 0s - loss: 1.4502 - accuracy: 0.5333
# Epoch 76: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.4502 - accuracy: 0.5333 - val_loss: 3.3172 - val_accuracy: 0.0000e+00
# Epoch 77/200
# 1/1 [==============================] - ETA: 0s - loss: 1.4536 - accuracy: 0.5333
# Epoch 77: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.4536 - accuracy: 0.5333 - val_loss: 3.2776 - val_accuracy: 0.0000e+00
# Epoch 78/200
# 1/1 [==============================] - ETA: 0s - loss: 1.4227 - accuracy: 0.6000
# Epoch 78: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.4227 - accuracy: 0.6000 - val_loss: 2.5156 - val_accuracy: 0.0000e+00
# Epoch 79/200
# 1/1 [==============================] - ETA: 0s - loss: 1.4331 - accuracy: 0.5778
# Epoch 79: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.4331 - accuracy: 0.5778 - val_loss: 2.8434 - val_accuracy: 0.0000e+00
# Epoch 80/200
# 1/1 [==============================] - ETA: 0s - loss: 1.3991 - accuracy: 0.5333
# Epoch 80: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3991 - accuracy: 0.5333 - val_loss: 3.5713 - val_accuracy: 0.0000e+00
# Epoch 81/200
# 1/1 [==============================] - ETA: 0s - loss: 1.4029 - accuracy: 0.5333
# Epoch 81: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.4029 - accuracy: 0.5333 - val_loss: 3.3241 - val_accuracy: 0.0000e+00
# Epoch 82/200
# 1/1 [==============================] - ETA: 0s - loss: 1.3862 - accuracy: 0.5778
# Epoch 82: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3862 - accuracy: 0.5778 - val_loss: 3.0260 - val_accuracy: 0.0000e+00
# Epoch 83/200
# 1/1 [==============================] - ETA: 0s - loss: 1.3606 - accuracy: 0.5556
# Epoch 83: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3606 - accuracy: 0.5556 - val_loss: 3.1190 - val_accuracy: 0.0000e+00
# Epoch 84/200
# 1/1 [==============================] - ETA: 0s - loss: 1.3721 - accuracy: 0.5556
# Epoch 84: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3721 - accuracy: 0.5556 - val_loss: 3.1549 - val_accuracy: 0.0000e+00
# Epoch 85/200
# 1/1 [==============================] - ETA: 0s - loss: 1.3423 - accuracy: 0.6000
# Epoch 85: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3423 - accuracy: 0.6000 - val_loss: 3.5492 - val_accuracy: 0.0000e+00
# Epoch 86/200
# 1/1 [==============================] - ETA: 0s - loss: 1.3354 - accuracy: 0.5556
# Epoch 86: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3354 - accuracy: 0.5556 - val_loss: 3.7181 - val_accuracy: 0.0000e+00
# Epoch 87/200
# 1/1 [==============================] - ETA: 0s - loss: 1.3267 - accuracy: 0.6000
# Epoch 87: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3267 - accuracy: 0.6000 - val_loss: 2.8582 - val_accuracy: 0.0000e+00
# Epoch 88/200
# 1/1 [==============================] - ETA: 0s - loss: 1.3210 - accuracy: 0.6222
# Epoch 88: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3210 - accuracy: 0.6222 - val_loss: 2.9746 - val_accuracy: 0.0000e+00
# Epoch 89/200
# 1/1 [==============================] - ETA: 0s - loss: 1.2999 - accuracy: 0.6222
# Epoch 89: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.2999 - accuracy: 0.6222 - val_loss: 3.7390 - val_accuracy: 0.0000e+00
# Epoch 90/200
# 1/1 [==============================] - ETA: 0s - loss: 1.2975 - accuracy: 0.6000
# Epoch 90: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.2975 - accuracy: 0.6000 - val_loss: 3.4960 - val_accuracy: 0.0000e+00
# Epoch 91/200
# 1/1 [==============================] - ETA: 0s - loss: 1.3029 - accuracy: 0.6000
# Epoch 91: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 42ms/step - loss: 1.3029 - accuracy: 0.6000 - val_loss: 3.5746 - val_accuracy: 0.0000e+00
# Epoch 92/200
# 1/1 [==============================] - ETA: 0s - loss: 1.2611 - accuracy: 0.5778
# Epoch 92: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.2611 - accuracy: 0.5778 - val_loss: 3.5851 - val_accuracy: 0.0000e+00
# Epoch 93/200
# 1/1 [==============================] - ETA: 0s - loss: 1.2900 - accuracy: 0.4889
# Epoch 93: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.2900 - accuracy: 0.4889 - val_loss: 2.8007 - val_accuracy: 0.0000e+00
# Epoch 94/200
# 1/1 [==============================] - ETA: 0s - loss: 1.3067 - accuracy: 0.5778
# Epoch 94: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3067 - accuracy: 0.5778 - val_loss: 3.4643 - val_accuracy: 0.0000e+00
# Epoch 95/200
# 1/1 [==============================] - ETA: 0s - loss: 1.2311 - accuracy: 0.6222
# Epoch 95: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.2311 - accuracy: 0.6222 - val_loss: 4.4361 - val_accuracy: 0.0000e+00
# Epoch 96/200
# 1/1 [==============================] - ETA: 0s - loss: 1.3090 - accuracy: 0.4444
# Epoch 96: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3090 - accuracy: 0.4444 - val_loss: 3.4431 - val_accuracy: 0.0000e+00
# Epoch 97/200
# 1/1 [==============================] - ETA: 0s - loss: 1.2467 - accuracy: 0.6222
# Epoch 97: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.2467 - accuracy: 0.6222 - val_loss: 3.1474 - val_accuracy: 0.0000e+00
# Epoch 98/200
# 1/1 [==============================] - ETA: 0s - loss: 1.2514 - accuracy: 0.6000
# Epoch 98: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.2514 - accuracy: 0.6000 - val_loss: 3.8245 - val_accuracy: 0.0000e+00
# Epoch 99/200
# 1/1 [==============================] - ETA: 0s - loss: 1.2314 - accuracy: 0.6000
# Epoch 99: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.2314 - accuracy: 0.6000 - val_loss: 3.9258 - val_accuracy: 0.0000e+00
# Epoch 100/200
# 1/1 [==============================] - ETA: 0s - loss: 1.1997 - accuracy: 0.6222
# Epoch 100: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.1997 - accuracy: 0.6222 - val_loss: 3.5008 - val_accuracy: 0.0000e+00
# Epoch 101/200
# 1/1 [==============================] - ETA: 0s - loss: 1.2059 - accuracy: 0.6000
# Epoch 101: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.2059 - accuracy: 0.6000 - val_loss: 3.5761 - val_accuracy: 0.0000e+00
# Epoch 102/200
# 1/1 [==============================] - ETA: 0s - loss: 1.1885 - accuracy: 0.6222
# Epoch 102: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.1885 - accuracy: 0.6222 - val_loss: 4.0161 - val_accuracy: 0.0000e+00
# Epoch 103/200
# 1/1 [==============================] - ETA: 0s - loss: 1.1787 - accuracy: 0.6444
# Epoch 103: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.1787 - accuracy: 0.6444 - val_loss: 3.7836 - val_accuracy: 0.0000e+00
# Epoch 104/200
# 1/1 [==============================] - ETA: 0s - loss: 1.1689 - accuracy: 0.6444
# Epoch 104: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.1689 - accuracy: 0.6444 - val_loss: 3.4203 - val_accuracy: 0.0000e+00
# Epoch 105/200
# 1/1 [==============================] - ETA: 0s - loss: 1.1651 - accuracy: 0.6000
# Epoch 105: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.1651 - accuracy: 0.6000 - val_loss: 3.8042 - val_accuracy: 0.0000e+00
# Epoch 106/200
# 1/1 [==============================] - ETA: 0s - loss: 1.1469 - accuracy: 0.6222
# Epoch 106: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.1469 - accuracy: 0.6222 - val_loss: 4.3286 - val_accuracy: 0.0000e+00
# Epoch 107/200
# 1/1 [==============================] - ETA: 0s - loss: 1.1473 - accuracy: 0.6667
# Epoch 107: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.1473 - accuracy: 0.6667 - val_loss: 3.8980 - val_accuracy: 0.0000e+00
# Epoch 108/200
# 1/1 [==============================] - ETA: 0s - loss: 1.1215 - accuracy: 0.6667
# Epoch 108: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.1215 - accuracy: 0.6667 - val_loss: 3.4878 - val_accuracy: 0.0000e+00
# Epoch 109/200
# 1/1 [==============================] - ETA: 0s - loss: 1.1275 - accuracy: 0.6889
# Epoch 109: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.1275 - accuracy: 0.6889 - val_loss: 3.8883 - val_accuracy: 0.0000e+00
# Epoch 110/200
# 1/1 [==============================] - ETA: 0s - loss: 1.1045 - accuracy: 0.6667
# Epoch 110: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.1045 - accuracy: 0.6667 - val_loss: 4.1855 - val_accuracy: 0.0000e+00
# Epoch 111/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0979 - accuracy: 0.6667
# Epoch 111: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0979 - accuracy: 0.6667 - val_loss: 3.8893 - val_accuracy: 0.0000e+00
# Epoch 112/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0972 - accuracy: 0.6667
# Epoch 112: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0972 - accuracy: 0.6667 - val_loss: 4.0697 - val_accuracy: 0.0000e+00
# Epoch 113/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0735 - accuracy: 0.6667
# Epoch 113: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0735 - accuracy: 0.6667 - val_loss: 3.9769 - val_accuracy: 0.0000e+00
# Epoch 114/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0686 - accuracy: 0.6889
# Epoch 114: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.0686 - accuracy: 0.6889 - val_loss: 3.6758 - val_accuracy: 0.0000e+00
# Epoch 115/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0819 - accuracy: 0.6667
# Epoch 115: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0819 - accuracy: 0.6667 - val_loss: 4.6678 - val_accuracy: 0.0000e+00
# Epoch 116/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0861 - accuracy: 0.6667
# Epoch 116: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0861 - accuracy: 0.6667 - val_loss: 3.8487 - val_accuracy: 0.0000e+00
# Epoch 117/200
# 1/1 [==============================] - ETA: 0s - loss: 1.1087 - accuracy: 0.6667
# Epoch 117: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.1087 - accuracy: 0.6667 - val_loss: 4.4399 - val_accuracy: 0.0000e+00
# Epoch 118/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0411 - accuracy: 0.6889
# Epoch 118: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.0411 - accuracy: 0.6889 - val_loss: 4.2085 - val_accuracy: 0.0000e+00
# Epoch 119/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0390 - accuracy: 0.6667
# Epoch 119: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.0390 - accuracy: 0.6667 - val_loss: 3.5468 - val_accuracy: 0.0000e+00
# Epoch 120/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0796 - accuracy: 0.6889
# Epoch 120: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 42ms/step - loss: 1.0796 - accuracy: 0.6889 - val_loss: 4.7921 - val_accuracy: 0.0000e+00
# Epoch 121/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0351 - accuracy: 0.6889
# Epoch 121: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0351 - accuracy: 0.6889 - val_loss: 4.6763 - val_accuracy: 0.0000e+00
# Epoch 122/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0137 - accuracy: 0.7111
# Epoch 122: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0137 - accuracy: 0.7111 - val_loss: 3.9563 - val_accuracy: 0.0000e+00
# Epoch 123/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0255 - accuracy: 0.6889
# Epoch 123: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.0255 - accuracy: 0.6889 - val_loss: 4.2632 - val_accuracy: 0.0000e+00
# Epoch 124/200
# 1/1 [==============================] - ETA: 0s - loss: 0.9937 - accuracy: 0.6889
# Epoch 124: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.9937 - accuracy: 0.6889 - val_loss: 4.4414 - val_accuracy: 0.0000e+00
# Epoch 125/200
# 1/1 [==============================] - ETA: 0s - loss: 0.9979 - accuracy: 0.6889
# Epoch 125: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.9979 - accuracy: 0.6889 - val_loss: 3.9805 - val_accuracy: 0.0000e+00
# Epoch 126/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0049 - accuracy: 0.6889
# Epoch 126: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0049 - accuracy: 0.6889 - val_loss: 4.6919 - val_accuracy: 0.0000e+00
# Epoch 127/200
# 1/1 [==============================] - ETA: 0s - loss: 0.9689 - accuracy: 0.7111
# Epoch 127: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9689 - accuracy: 0.7111 - val_loss: 5.1748 - val_accuracy: 0.0000e+00
# Epoch 128/200
# 1/1 [==============================] - ETA: 0s - loss: 0.9867 - accuracy: 0.7111
# Epoch 128: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.9867 - accuracy: 0.7111 - val_loss: 3.9259 - val_accuracy: 0.0000e+00
# Epoch 129/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0033 - accuracy: 0.6889
# Epoch 129: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0033 - accuracy: 0.6889 - val_loss: 4.5816 - val_accuracy: 0.0000e+00
# Epoch 130/200
# 1/1 [==============================] - ETA: 0s - loss: 0.9461 - accuracy: 0.7333
# Epoch 130: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.9461 - accuracy: 0.7333 - val_loss: 5.0640 - val_accuracy: 0.0000e+00
# Epoch 131/200
# 1/1 [==============================] - ETA: 0s - loss: 0.9645 - accuracy: 0.7111
# Epoch 131: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9645 - accuracy: 0.7111 - val_loss: 3.9928 - val_accuracy: 0.0000e+00
# Epoch 132/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0258 - accuracy: 0.6444
# Epoch 132: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0258 - accuracy: 0.6444 - val_loss: 5.3134 - val_accuracy: 0.0000e+00
# Epoch 133/200
# 1/1 [==============================] - ETA: 0s - loss: 0.9401 - accuracy: 0.7333
# Epoch 133: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.9401 - accuracy: 0.7333 - val_loss: 5.4765 - val_accuracy: 0.0000e+00
# Epoch 134/200
# 1/1 [==============================] - ETA: 0s - loss: 0.9597 - accuracy: 0.6889
# Epoch 134: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9597 - accuracy: 0.6889 - val_loss: 3.7799 - val_accuracy: 0.0000e+00
# Epoch 135/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0279 - accuracy: 0.6444
# Epoch 135: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0279 - accuracy: 0.6444 - val_loss: 4.7539 - val_accuracy: 0.0000e+00
# Epoch 136/200
# 1/1 [==============================] - ETA: 0s - loss: 0.9067 - accuracy: 0.7556
# Epoch 136: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.9067 - accuracy: 0.7556 - val_loss: 6.2175 - val_accuracy: 0.0000e+00
# Epoch 137/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0392 - accuracy: 0.5778
# Epoch 137: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0392 - accuracy: 0.5778 - val_loss: 4.0491 - val_accuracy: 0.0000e+00
# Epoch 138/200
# 1/1 [==============================] - ETA: 0s - loss: 1.1014 - accuracy: 0.5778
# Epoch 138: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 1.1014 - accuracy: 0.5778 - val_loss: 4.4910 - val_accuracy: 0.0000e+00
# Epoch 139/200
# 1/1 [==============================] - ETA: 0s - loss: 0.9284 - accuracy: 0.7111
# Epoch 139: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9284 - accuracy: 0.7111 - val_loss: 6.2552 - val_accuracy: 0.0000e+00
# Epoch 140/200
# 1/1 [==============================] - ETA: 0s - loss: 1.0012 - accuracy: 0.6222
# Epoch 140: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0012 - accuracy: 0.6222 - val_loss: 4.7631 - val_accuracy: 0.0000e+00
# Epoch 141/200
# 1/1 [==============================] - ETA: 0s - loss: 0.8921 - accuracy: 0.7556
# Epoch 141: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.8921 - accuracy: 0.7556 - val_loss: 3.9639 - val_accuracy: 0.0000e+00
# Epoch 142/200
# 1/1 [==============================] - ETA: 0s - loss: 0.9385 - accuracy: 0.7111
# Epoch 142: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9385 - accuracy: 0.7111 - val_loss: 4.3584 - val_accuracy: 0.0000e+00
# Epoch 143/200
# 1/1 [==============================] - ETA: 0s - loss: 0.8963 - accuracy: 0.7333
# Epoch 143: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8963 - accuracy: 0.7333 - val_loss: 5.5211 - val_accuracy: 0.0000e+00
# Epoch 144/200
# 1/1 [==============================] - ETA: 0s - loss: 0.8881 - accuracy: 0.7778
# Epoch 144: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8881 - accuracy: 0.7778 - val_loss: 5.8931 - val_accuracy: 0.0000e+00
# Epoch 145/200
# 1/1 [==============================] - ETA: 0s - loss: 0.9004 - accuracy: 0.7333
# Epoch 145: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.9004 - accuracy: 0.7333 - val_loss: 4.6403 - val_accuracy: 0.0000e+00
# Epoch 146/200
# 1/1 [==============================] - ETA: 0s - loss: 0.8633 - accuracy: 0.7556
# Epoch 146: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8633 - accuracy: 0.7556 - val_loss: 4.1772 - val_accuracy: 0.0000e+00
# Epoch 147/200
# 1/1 [==============================] - ETA: 0s - loss: 0.8921 - accuracy: 0.7333
# Epoch 147: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8921 - accuracy: 0.7333 - val_loss: 4.6670 - val_accuracy: 0.0000e+00
# Epoch 148/200
# 1/1 [==============================] - ETA: 0s - loss: 0.8503 - accuracy: 0.7333
# Epoch 148: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8503 - accuracy: 0.7333 - val_loss: 5.7412 - val_accuracy: 0.0000e+00
# Epoch 149/200
# 1/1 [==============================] - ETA: 0s - loss: 0.8666 - accuracy: 0.7778
# Epoch 149: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8666 - accuracy: 0.7778 - val_loss: 5.4083 - val_accuracy: 0.0000e+00
# Epoch 150/200
# 1/1 [==============================] - ETA: 0s - loss: 0.8389 - accuracy: 0.7778
# Epoch 150: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8389 - accuracy: 0.7778 - val_loss: 4.8232 - val_accuracy: 0.0000e+00
# Epoch 151/200
# 1/1 [==============================] - ETA: 0s - loss: 0.8429 - accuracy: 0.8000
# Epoch 151: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8429 - accuracy: 0.8000 - val_loss: 4.7707 - val_accuracy: 0.0000e+00
# Epoch 152/200
# 1/1 [==============================] - ETA: 0s - loss: 0.8308 - accuracy: 0.8000
# Epoch 152: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8308 - accuracy: 0.8000 - val_loss: 5.3126 - val_accuracy: 0.0000e+00
# Epoch 153/200
# 1/1 [==============================] - ETA: 0s - loss: 0.8217 - accuracy: 0.7778
# Epoch 153: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8217 - accuracy: 0.7778 - val_loss: 5.5190 - val_accuracy: 0.0000e+00
# Epoch 154/200
# 1/1 [==============================] - ETA: 0s - loss: 0.8218 - accuracy: 0.7556
# Epoch 154: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8218 - accuracy: 0.7556 - val_loss: 5.0533 - val_accuracy: 0.0000e+00
# Epoch 155/200
# 1/1 [==============================] - ETA: 0s - loss: 0.8071 - accuracy: 0.8000
# Epoch 155: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8071 - accuracy: 0.8000 - val_loss: 5.0692 - val_accuracy: 0.0000e+00
# Epoch 156/200
# 1/1 [==============================] - ETA: 0s - loss: 0.8104 - accuracy: 0.8000
# Epoch 156: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8104 - accuracy: 0.8000 - val_loss: 5.6614 - val_accuracy: 0.0000e+00
# Epoch 157/200
# 1/1 [==============================] - ETA: 0s - loss: 0.7909 - accuracy: 0.8000
# Epoch 157: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.7909 - accuracy: 0.8000 - val_loss: 5.8456 - val_accuracy: 0.0000e+00
# Epoch 158/200
# 1/1 [==============================] - ETA: 0s - loss: 0.7946 - accuracy: 0.7778
# Epoch 158: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7946 - accuracy: 0.7778 - val_loss: 5.1567 - val_accuracy: 0.0000e+00
# Epoch 159/200
# 1/1 [==============================] - ETA: 0s - loss: 0.7814 - accuracy: 0.8000
# Epoch 159: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.7814 - accuracy: 0.8000 - val_loss: 5.1960 - val_accuracy: 0.0000e+00
# Epoch 160/200
# 1/1 [==============================] - ETA: 0s - loss: 0.7787 - accuracy: 0.8000
# Epoch 160: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7787 - accuracy: 0.8000 - val_loss: 6.0763 - val_accuracy: 0.0000e+00
# Epoch 161/200
# 1/1 [==============================] - ETA: 0s - loss: 0.7671 - accuracy: 0.7778
# Epoch 161: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.7671 - accuracy: 0.7778 - val_loss: 6.0079 - val_accuracy: 0.0000e+00
# Epoch 162/200
# 1/1 [==============================] - ETA: 0s - loss: 0.7573 - accuracy: 0.7778
# Epoch 162: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7573 - accuracy: 0.7778 - val_loss: 5.3859 - val_accuracy: 0.0000e+00
# Epoch 163/200
# 1/1 [==============================] - ETA: 0s - loss: 0.7553 - accuracy: 0.8000
# Epoch 163: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7553 - accuracy: 0.8000 - val_loss: 5.6377 - val_accuracy: 0.0000e+00
# Epoch 164/200
# 1/1 [==============================] - ETA: 0s - loss: 0.7430 - accuracy: 0.8000
# Epoch 164: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.7430 - accuracy: 0.8000 - val_loss: 6.3681 - val_accuracy: 0.0000e+00
# Epoch 165/200
# 1/1 [==============================] - ETA: 0s - loss: 0.7458 - accuracy: 0.8000
# Epoch 165: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.7458 - accuracy: 0.8000 - val_loss: 5.5450 - val_accuracy: 0.0000e+00
# Epoch 166/200
# 1/1 [==============================] - ETA: 0s - loss: 0.7330 - accuracy: 0.8222
# Epoch 166: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.7330 - accuracy: 0.8222 - val_loss: 5.4756 - val_accuracy: 0.0000e+00
# Epoch 167/200
# 1/1 [==============================] - ETA: 0s - loss: 0.7279 - accuracy: 0.8222
# Epoch 167: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.7279 - accuracy: 0.8222 - val_loss: 6.1788 - val_accuracy: 0.0000e+00
# Epoch 168/200
# 1/1 [==============================] - ETA: 0s - loss: 0.7225 - accuracy: 0.8222
# Epoch 168: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7225 - accuracy: 0.8222 - val_loss: 5.8681 - val_accuracy: 0.0000e+00
# Epoch 169/200
# 1/1 [==============================] - ETA: 0s - loss: 0.7112 - accuracy: 0.8222
# Epoch 169: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 42ms/step - loss: 0.7112 - accuracy: 0.8222 - val_loss: 5.4927 - val_accuracy: 0.0000e+00
# Epoch 170/200
# 1/1 [==============================] - ETA: 0s - loss: 0.7094 - accuracy: 0.8222
# Epoch 170: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.7094 - accuracy: 0.8222 - val_loss: 5.8204 - val_accuracy: 0.0000e+00
# Epoch 171/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6986 - accuracy: 0.8222
# Epoch 171: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6986 - accuracy: 0.8222 - val_loss: 6.1195 - val_accuracy: 0.0000e+00
# Epoch 172/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6970 - accuracy: 0.8222
# Epoch 172: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6970 - accuracy: 0.8222 - val_loss: 5.5531 - val_accuracy: 0.0000e+00
# Epoch 173/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6892 - accuracy: 0.8222
# Epoch 173: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6892 - accuracy: 0.8222 - val_loss: 5.5305 - val_accuracy: 0.0000e+00
# Epoch 174/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6847 - accuracy: 0.8222
# Epoch 174: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6847 - accuracy: 0.8222 - val_loss: 6.0615 - val_accuracy: 0.0000e+00
# Epoch 175/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6796 - accuracy: 0.8222
# Epoch 175: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6796 - accuracy: 0.8222 - val_loss: 5.9385 - val_accuracy: 0.0000e+00
# Epoch 176/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6730 - accuracy: 0.8222
# Epoch 176: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6730 - accuracy: 0.8222 - val_loss: 5.5575 - val_accuracy: 0.0000e+00
# Epoch 177/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6696 - accuracy: 0.8444
# Epoch 177: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6696 - accuracy: 0.8444 - val_loss: 5.6781 - val_accuracy: 0.0000e+00
# Epoch 178/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6632 - accuracy: 0.8444
# Epoch 178: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6632 - accuracy: 0.8444 - val_loss: 5.9961 - val_accuracy: 0.0000e+00
# Epoch 179/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6601 - accuracy: 0.8222
# Epoch 179: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6601 - accuracy: 0.8222 - val_loss: 5.8419 - val_accuracy: 0.0000e+00
# Epoch 180/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6537 - accuracy: 0.8222
# Epoch 180: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6537 - accuracy: 0.8222 - val_loss: 5.6659 - val_accuracy: 0.0000e+00
# Epoch 181/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6509 - accuracy: 0.8444
# Epoch 181: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6509 - accuracy: 0.8444 - val_loss: 5.8425 - val_accuracy: 0.0000e+00
# Epoch 182/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6447 - accuracy: 0.8444
# Epoch 182: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6447 - accuracy: 0.8444 - val_loss: 5.9418 - val_accuracy: 0.0000e+00
# Epoch 183/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6415 - accuracy: 0.8222
# Epoch 183: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6415 - accuracy: 0.8222 - val_loss: 5.7357 - val_accuracy: 0.0000e+00
# Epoch 184/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6356 - accuracy: 0.8444
# Epoch 184: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6356 - accuracy: 0.8444 - val_loss: 5.6707 - val_accuracy: 0.0000e+00
# Epoch 185/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6314 - accuracy: 0.8444
# Epoch 185: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6314 - accuracy: 0.8444 - val_loss: 5.9095 - val_accuracy: 0.0000e+00
# Epoch 186/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6254 - accuracy: 0.8222
# Epoch 186: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6254 - accuracy: 0.8222 - val_loss: 5.8838 - val_accuracy: 0.0000e+00
# Epoch 187/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6198 - accuracy: 0.8222
# Epoch 187: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6198 - accuracy: 0.8222 - val_loss: 5.6669 - val_accuracy: 0.0000e+00
# Epoch 188/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6152 - accuracy: 0.8444
# Epoch 188: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6152 - accuracy: 0.8444 - val_loss: 6.0430 - val_accuracy: 0.0000e+00
# Epoch 189/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6092 - accuracy: 0.8222
# Epoch 189: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6092 - accuracy: 0.8222 - val_loss: 5.7899 - val_accuracy: 0.0000e+00
# Epoch 190/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6023 - accuracy: 0.8222
# Epoch 190: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6023 - accuracy: 0.8222 - val_loss: 5.8600 - val_accuracy: 0.0000e+00
# Epoch 191/200
# 1/1 [==============================] - ETA: 0s - loss: 0.5961 - accuracy: 0.8222
# Epoch 191: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5961 - accuracy: 0.8222 - val_loss: 6.0845 - val_accuracy: 0.0000e+00
# Epoch 192/200
# 1/1 [==============================] - ETA: 0s - loss: 0.5919 - accuracy: 0.8222
# Epoch 192: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5919 - accuracy: 0.8222 - val_loss: 5.6668 - val_accuracy: 0.0000e+00
# Epoch 193/200
# 1/1 [==============================] - ETA: 0s - loss: 0.5894 - accuracy: 0.8222
# Epoch 193: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5894 - accuracy: 0.8222 - val_loss: 6.3652 - val_accuracy: 0.0000e+00
# Epoch 194/200
# 1/1 [==============================] - ETA: 0s - loss: 0.5904 - accuracy: 0.8444
# Epoch 194: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5904 - accuracy: 0.8444 - val_loss: 5.2627 - val_accuracy: 0.0000e+00
# Epoch 195/200
# 1/1 [==============================] - ETA: 0s - loss: 0.5980 - accuracy: 0.8667
# Epoch 195: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5980 - accuracy: 0.8667 - val_loss: 6.7180 - val_accuracy: 0.0000e+00
# Epoch 196/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6018 - accuracy: 0.8444
# Epoch 196: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6018 - accuracy: 0.8444 - val_loss: 4.7816 - val_accuracy: 0.0000e+00
# Epoch 197/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6278 - accuracy: 0.8667
# Epoch 197: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6278 - accuracy: 0.8667 - val_loss: 7.0642 - val_accuracy: 0.0000e+00
# Epoch 198/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6388 - accuracy: 0.8222
# Epoch 198: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6388 - accuracy: 0.8222 - val_loss: 4.1714 - val_accuracy: 0.0000e+00
# Epoch 199/200
# 1/1 [==============================] - ETA: 0s - loss: 0.6964 - accuracy: 0.8222
# Epoch 199: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6964 - accuracy: 0.8222 - val_loss: 6.6510 - val_accuracy: 0.0000e+00
# Epoch 200/200
# 1/1 [==============================] - ETA: 0s - loss: 0.5996 - accuracy: 0.8444
# Epoch 200: val_loss did not improve from 1.71409
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5996 - accuracy: 0.8444 - val_loss: 6.6091 - val_accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 2.0717 - accuracy: 0.2000
# Test accuracy: 20.0%
# C:\Users\SMHRD\anaconda3\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
def prepare_single_video(frames, skeletons, hands, arm_angles):
    num_frames = len(frames)
    video_length = min(MAX_SEQ_LENGTH, num_frames)

    # 데이터 초기화
    frame_mask = np.zeros((1, MAX_SEQ_LENGTH), dtype="bool")
    frame_features = np.zeros((1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32")
    frame_skeletons = np.zeros((1, MAX_SEQ_LENGTH, SKELETON_FEATURES), dtype="float32")
    frame_hands = np.zeros((1, MAX_SEQ_LENGTH, HAND_FEATURES), dtype="float32")
    frame_arm_angles = np.zeros((1, MAX_SEQ_LENGTH, ARM_ANGLE_FEATURES), dtype="float32")
    
    feature_extractor = Sequential([
        Xception(weights="imagenet",
        include_top=False,
        pooling="avg",),
        Dense(NUM_FEATURES, activation='relu')
    ])
    
    for j in range(video_length):
        # 이미지 데이터 전처리 및 특징 추출
        image_feature = preprocess_image(frames[j])
        image_feature = np.expand_dims(image_feature, axis=0)
        feature_result = feature_extractor.predict(image_feature)

        # 특징 저장
        frame_features[0, j] = feature_result

        # Mediapipe 데이터 전처리
        skeleton_feature = preprocess_skeleton_data(skeletons[j])
        hand_feature = preprocess_hand_data(hands[j])        
        arm_angle_feature = np.array(arm_angles[j])

        # 데이터 저장
        frame_skeletons[0, j] = skeleton_feature
        frame_hands[0, j] = hand_feature
        frame_mask[0, j] = 1        
        frame_arm_angles[0, j] = arm_angle_feature

    return frame_features, frame_skeletons, frame_hands, frame_mask, frame_arm_angles

# %%
def sequence_prediction(path, sequence_model):
    class_vocab = test_label_processor.get_vocabulary()
    frames, skeletons, hands, arm_angles = load_video(path)    
    try:
        num_frames = len(frames)
    except IndexError:
        print("Error: Unable to determine the number of frames. Frames shape:", frames.shape)
        return None
    
    # EfficientNetB0 모델을 사용하여 프레임에서 특징 추출
    frame_features, frame_skeletons, frame_hands, frame_mask, frame_arm_angles = prepare_single_video(frames, skeletons, hands, arm_angles)
    
    # LSTM 모델을 사용하여 예측 수행
    probabilities = sequence_model.predict([frame_features, frame_skeletons, frame_hands, frame_arm_angles, frame_mask])[0]
    
    # 가장 가능성 높은 레이블 출력
    for i in np.argsort(probabilities)[::-1]:
        print(f"{class_vocab[i]} : {probabilities[i] * 100:5.2f}%")
    
    return frames

# %%
test_video = np.random.choice(test_df["video_name"].values.tolist())
print(f"Test video path: {test_video}")

test_frames = sequence_prediction(test_video,sequence_model)
# Out:
# Test video path: data/test/NIA_SL_SEN0203/NIA_SL_SEN0203_REAL13_F.mp4
# 1/1 [==============================] - 1s 797ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 2s 2s/step
# NIA_SL_SEN0011 : 100.00%
# NIA_SL_SEN0013 :  0.00%
# NIA_SL_SEN0203 :  0.00%
# NIA_SL_SEN0159 :  0.00%
# NIA_SL_SEN0275 :  0.00%

# %%
def sequence_prediction_with_voting(path, model1, model2, model3):
    class_vocab = test_label_processor.get_vocabulary()
    frames, skeletons, hands, arm_angles = load_video(path)
    try:
        num_frames = len(frames)
    except IndexError:
        print("Error: Unable to determine the number of frames. Frames shape:", frames.shape)
        return None
    
    # 데이터 준비
    frame_features, frame_skeletons, frame_hands, frame_mask, frame_arm_angles = prepare_single_video(frames, skeletons, hands, arm_angles)
    
    # 각 모델로부터 예측 수행
    probabilities1 = model1.predict([frame_features, frame_skeletons, frame_hands, frame_arm_angles, frame_mask])[0]
    probabilities2 = model2.predict([frame_features, frame_skeletons, frame_hands, frame_arm_angles, frame_mask])[0]
    probabilities3 = model3.predict([frame_features, frame_skeletons, frame_hands, frame_arm_angles, frame_mask])[0]
    
    # 보팅을 위한 예측 레이블 결정
    final_prediction = vote([probabilities1, probabilities2, probabilities3], class_vocab)
    
    # 최종 레이블 출력
    print(f"Final prediction: {final_prediction}")
    return frames

def vote(probability_lists, class_vocab):
    votes = [np.argmax(prob) for prob in probability_lists]
    final_vote = max(set(votes), key=votes.count)
    return class_vocab[final_vote]

# %%
from tensorflow.keras.models import load_model

# 모델 파일 경로 지정
vgg_model_path = 'VGG16_model.h5'
xception_model_path = 'Xception_model.h5'
dence_model_path = 'Dence_model.h5'

# 모델 불러오기
vgg_model = load_model(vgg_model_path)
xception_model = load_model(xception_model_path)
dence_model = load_model(dence_model_path)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[78], line 9
#       6 dence_model_path = 'Dence_model.h5'
#       8 # 모델 불러오기
# ----> 9 vgg_model = load_model(vgg_model_path)
#      10 xception_model = load_model(xception_model_path)
#      11 dence_model = load_model(dence_model_path)
#
# File ~\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py:238, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     230     return saving_lib.load_model(
#     231         filepath,
#     232         custom_objects=custom_objects,
#     233         compile=compile,
#     234         safe_mode=safe_mode,
#     235     )
#     237 # Legacy case.
# --> 238 return legacy_sm_saving_lib.load_model(
#     239     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     240 )
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\lib\io\file_io.py:703, in is_directory_v2(path)
#     694 """Returns whether the path is a directory or not.
#     695
#     696 Args:
#    (...)
#     700   True, if the path is a directory; False otherwise
#     701 """
#     702 try:
# --> 703   return _pywrap_file_io.IsDirectory(compat.path_to_bytes(path))
#     704 except errors.OpError:
#     705   return False
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe4 in position 21: invalid continuation byte

# %%
test_video = np.random.choice(test_df["video_name"].values.tolist())
print(f"Test video path: {test_video}")

test_frames = sequence_prediction_with_voting(test_video,vgg_model,xception_model,dence_model)

# %%
# TensorFlow 버전 확인
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.13.0
